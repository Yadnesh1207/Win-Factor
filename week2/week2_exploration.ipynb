# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('mw_pw_profiles.csv')
# Out:
# /tmp/ipykernel_6800/1418854009.py:1: DtypeWarning: Columns (32,45) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('mw_pw_profiles.csv')

# %%
data.head()
# Out:
#   player_id match_id  gender  balls_per_over  start_date  \
# 0  00015688  1158348  female               6  2018-08-21
# 1  00015688  1182644  female               6  2019-05-05
# 2  00015688  1275107  female               6  2021-09-09
# 3  00015688  1275113  female               6  2021-09-15
# 4  00015688  1275125  female               6  2021-09-14
#
#                                          series_name match_type  name_x  \
# 0   Botswana Cricket Association Women's T20I Series        T20  M King
# 1  ICC Women's T20 World Cup Africa Region Qualifier        T20  M King
# 2  ICC Women's T20 World Cup Africa Region Qualifier        T20  M King
# 3  ICC Women's T20 World Cup Africa Region Qualifier        T20  M King
# 4  ICC Women's T20 World Cup Africa Region Qualifier        T20  M King
#
#    runs_scored  player_out  ...  key_pulse  key_pulse_2  full_name  \
# 0           10           1  ...        NaN          NaN        NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 416712 entries, 0 to 416711
# Data columns (total 58 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   player_id              416712 non-null  object
#  1   match_id               416712 non-null  object
#  2   gender                 416712 non-null  object
#  3   balls_per_over         416712 non-null  int64
#  4   start_date             416712 non-null  object
#  5   series_name            414752 non-null  object
#  6   match_type             416712 non-null  object
#  7   name_x                 416712 non-null  object
#  8   runs_scored            416712 non-null  int64
#  9   player_out             416712 non-null  int64
#  10  balls_faced            416712 non-null  int64
#  11  fours_scored           416712 non-null  int64
#  12  sixes_scored           416712 non-null  int64
#  13  catches_taken          416712 non-null  int64
# ...

# %%
data.describe()
# Out:
#        balls_per_over    runs_scored     player_out    balls_faced  \
# count   416712.000000  416712.000000  416712.000000  416712.000000
# mean         5.986590      17.626197       0.689049      23.514485
# std          0.115022      27.435281       0.596259      42.306644
# min          5.000000       0.000000       0.000000       0.000000
# 25%          6.000000       0.000000       0.000000       1.000000
# 50%          6.000000       6.000000       1.000000       9.000000
# 75%          6.000000      24.000000       1.000000      27.000000
# max          6.000000     424.000000       2.000000     673.000000
#
#         fours_scored   sixes_scored  catches_taken  run_out_direct  \
# count  416712.000000  416712.000000  416712.000000   416712.000000
# mean        1.801095       0.358939       0.392173        0.020650
# std         3.263833       0.950220       0.752152        0.146137
# min         0.000000       0.000000       0.000000        0.000000
# ...

# %%
for col in data.columns:
    uni = data[col].nunique()
    print("unique values in",col,"=",uni)
# Out:
# unique values in player_id = 11771
# unique values in match_id = 18896
# unique values in gender = 2
# unique values in balls_per_over = 2
# unique values in start_date = 5494
# unique values in series_name = 964
# unique values in match_type = 6
# unique values in name_x = 11666
# unique values in runs_scored = 328
# unique values in player_out = 3
# unique values in balls_faced = 529
# unique values in fours_scored = 50
# unique values in sixes_scored = 21
# unique values in catches_taken = 13
# unique values in run_out_direct = 5
# unique values in run_out_throw = 6
# unique values in stumpings_done = 6
# unique values in out_kind = 14
# unique values in dot_balls_as_batsman = 409
# unique values in order_seen = 13
# unique values in balls_bowled = 499
# unique values in runs_conceded = 283
# unique values in wickets_taken = 17
# unique values in bowled_done = 8
# unique values in lbw_done = 10
# unique values in maidens = 39
# unique values in dot_balls_as_bowler = 403
# ...

# %%
data.drop(['batting_style', 'bowling_style','playing_role','teams','full_name','key_opta_2','key_cricinfo_3','key_cricketarchive_2'], axis=1, inplace=True)

# %%
data.to_csv('clean_data.csv',index=False)

# %%
data = pd.read_csv('clean_data.csv')
# Out:
# /tmp/ipykernel_6800/1445421276.py:1: DtypeWarning: Columns (32,43) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('clean_data.csv')

# %%
for col in data.columns:
    uni = data[col].nunique()
    print("unique values in",col,"=",uni)
# Out:
# unique values in player_id = 11771
# unique values in match_id = 18896
# unique values in gender = 2
# unique values in balls_per_over = 2
# unique values in start_date = 5494
# unique values in series_name = 964
# unique values in match_type = 6
# unique values in name_x = 11666
# unique values in runs_scored = 328
# unique values in player_out = 3
# unique values in balls_faced = 529
# unique values in fours_scored = 50
# unique values in sixes_scored = 21
# unique values in catches_taken = 13
# unique values in run_out_direct = 5
# unique values in run_out_throw = 6
# unique values in stumpings_done = 6
# unique values in out_kind = 14
# unique values in dot_balls_as_batsman = 409
# unique values in order_seen = 13
# unique values in balls_bowled = 499
# unique values in runs_conceded = 283
# unique values in wickets_taken = 17
# unique values in bowled_done = 8
# unique values in lbw_done = 10
# unique values in maidens = 39
# unique values in dot_balls_as_bowler = 403
# ...

# %%
male_data = data[data['gender'] == 'male']
female_data = data[data['gender'] == 'female']

# %%
male_data.drop(['gender'], axis=1, inplace=True)
female_data.drop(['gender'], axis=1, inplace=True)
# Out:
# /tmp/ipykernel_6800/925441257.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male_data.drop(['gender'], axis=1, inplace=True)
# /tmp/ipykernel_6800/925441257.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female_data.drop(['gender'], axis=1, inplace=True)

# %%
male_data.to_csv('male_data.csv',index=False)
female_data.to_csv('female_data.csv',index=False)

# %%
male_data.head()
# Out:
#   player_id match_id  balls_per_over  start_date  \
# 5  00029c30  1163062               6  2018-11-01
# 6  00029c30  1283024               6  2021-10-16
# 7  00029c30  1283026               6  2021-10-17
# 8  00029c30  1283029               6  2021-10-19
# 9  00029c30  1283033               6  2021-10-20
#
#                                          series_name match_type     name_x  \
# 5       ICC World Twenty20 Africa Region Qualifier C       IT20  M Mwamadi
# 6  ICC Men's T20 World Cup Sub Regional Africa Qu...        T20  M Mwamadi
# 7  ICC Men's T20 World Cup Sub Regional Africa Qu...        T20  M Mwamadi
# 8  ICC Men's T20 World Cup Sub Regional Africa Qu...        T20  M Mwamadi
# 9  ICC Men's T20 World Cup Sub Regional Africa Qu...        T20  M Mwamadi
#
#    runs_scored  player_out  balls_faced  ...  key_cricketarchive  \
# 5            0           0            0  ...                 NaN
# 6            0           0            2  ...                 NaN
# ...

# %%
for col in male_data.columns:
    uni = male_data[col].nunique()
    print("unique values in",col,"=",uni)
# Out:
# unique values in player_id = 8779
# unique values in match_id = 15382
# unique values in balls_per_over = 2
# unique values in start_date = 5308
# unique values in series_name = 683
# unique values in match_type = 6
# unique values in name_x = 8698
# unique values in runs_scored = 328
# unique values in player_out = 3
# unique values in balls_faced = 529
# unique values in fours_scored = 50
# unique values in sixes_scored = 21
# unique values in catches_taken = 13
# unique values in run_out_direct = 4
# unique values in run_out_throw = 5
# unique values in stumpings_done = 5
# unique values in out_kind = 14
# unique values in dot_balls_as_batsman = 408
# unique values in order_seen = 13
# unique values in balls_bowled = 499
# unique values in runs_conceded = 283
# unique values in wickets_taken = 17
# unique values in bowled_done = 8
# unique values in lbw_done = 10
# unique values in maidens = 39
# unique values in dot_balls_as_bowler = 402
# unique values in player_team = 329
# ...

# %%
sns.pairplot(male_data, vars= [
    'runs_scored', 'balls_faced',
    'wickets_taken',
    'dot_balls_as_batsman', 'dot_balls_as_bowler',
    'catches_taken','fantasy_score_bowling', 'fantasy_score_total'
],  kind = 'scatter' , diag_kind = 'kde')
plt.show()

# %%
numeric_cols = [
    'runs_scored', 'balls_faced', 'fours_scored', 'sixes_scored',
    'wickets_taken', 'runs_conceded', 'maidens',
    'dot_balls_as_batsman', 'dot_balls_as_bowler',
    'catches_taken','fantasy_score_batting','fantasy_score_bowling', 'fantasy_score_total'
]



# Calculate correlation matrix
corr = male_data[numeric_cols].corr()


# Set up the matplotlib figure
plt.figure(figsize=(12, 10))

# Draw the heatmap with the mask
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", square=True, linewidths=0.5)
plt.title("Pairwise Correlation Heatmap")
plt.tight_layout()
plt.show()

# %% [markdown]
# take runs scored,wickets taken
